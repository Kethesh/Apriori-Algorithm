# %%
import pandas as pd
import numpy as np

# %%
basket = pd.read_csv("basket.csv")
basket.head()
# Out:
#              0                   1                    2       3    4    5  \
# 0   whole milk              pastry          salty snack     NaN  NaN  NaN
# 1      sausage          whole milk  semi-finished bread  yogurt  NaN  NaN
# 2         soda  pickled vegetables                  NaN     NaN  NaN  NaN
# 3  canned beer     misc. beverages                  NaN     NaN  NaN  NaN
# 4      sausage    hygiene articles                  NaN     NaN  NaN  NaN
#
#      6    7    8    9   10
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN

# %%
basket
# Out:
#                            0                   1                    2       3  \
# 0                 whole milk              pastry          salty snack     NaN
# 1                    sausage          whole milk  semi-finished bread  yogurt
# 2                       soda  pickled vegetables                  NaN     NaN
# 3                canned beer     misc. beverages                  NaN     NaN
# 4                    sausage    hygiene articles                  NaN     NaN
# ...                      ...                 ...                  ...     ...
# 14958            butter milk  whipped/sour cream                  NaN     NaN
# 14959          bottled water               herbs                  NaN     NaN
# 14960  fruit/vegetable juice              onions                  NaN     NaN
# 14961           bottled beer    other vegetables                  NaN     NaN
# 14962                   soda     root vegetables  semi-finished bread     NaN
#
# ...

# %%
gro_data = pd.read_csv("Groceries data.csv")
gro_data.head()
# Out:
#    Member_number        Date   itemDescription  year  month  day  day_of_week
# 0           1808  2015-07-21    tropical fruit  2015      7   21            1
# 1           2552  2015-05-01        whole milk  2015      5    1            4
# 2           2300  2015-09-19         pip fruit  2015      9   19            5
# 3           1187  2015-12-12  other vegetables  2015     12   12            5
# 4           3037  2015-01-02        whole milk  2015      1    2            4

# %%
basket.head()
# Out:
#              0                   1                    2       3    4    5  \
# 0   whole milk              pastry          salty snack     NaN  NaN  NaN
# 1      sausage          whole milk  semi-finished bread  yogurt  NaN  NaN
# 2         soda  pickled vegetables                  NaN     NaN  NaN  NaN
# 3  canned beer     misc. beverages                  NaN     NaN  NaN  NaN
# 4      sausage    hygiene articles                  NaN     NaN  NaN  NaN
#
#      6    7    8    9   10
# 0  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN

# %%
basket.shape[0]
# Out:
# 14963

# %%
# !pip install apyori
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
transactions = []

# %%
for i in range(14963):
    transaction_items = [str(basket.values[i, j]) for j in range(11)]
    transactions.append(transaction_items)

# %%
transaction_items
# Out:
# ['soda',
#  'root vegetables',
#  'semi-finished bread',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan']

# %%
transactions = [str(basket.values[i, j]) for i in range(14963) for j in range(11)]
result_transactions = list(transactions)
result_transactions
# Out:
# ['whole milk',
#  'pastry',
#  'salty snack',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'sausage',
#  'whole milk',
#  'semi-finished bread',
#  'yogurt',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'soda',
#  'pickled vegetables',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'canned beer',
#  'misc. beverages',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'sausage',
#  'hygiene articles',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'sausage',
#  'whole milk',
#  'rolls/buns',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'whole milk',
#  'soda',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'frankfurter',
#  'soda',
#  'whipped/sour cream',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
# ...

# %%
transactions
# Out:
# ['whole milk',
#  'pastry',
#  'salty snack',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'sausage',
#  'whole milk',
#  'semi-finished bread',
#  'yogurt',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'soda',
#  'pickled vegetables',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'canned beer',
#  'misc. beverages',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'sausage',
#  'hygiene articles',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'sausage',
#  'whole milk',
#  'rolls/buns',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'whole milk',
#  'soda',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'frankfurter',
#  'soda',
#  'whipped/sour cream',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
# ...

# %%
from apyori import apriori

# %%
rules = apriori(transactions=transactions, min_support=0.3, min_confidence=0.5, min_lift=1, min_length=1, max_length=4)

# %%
rules
# Out:
# <generator object apriori at 0x000002013725CCA0>

# %%
results = list(rules)

# %%
print(results)
print("\n")
# Out:
# [RelationRecord(items=frozenset({'a'}), support=0.9011561852569672, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'a'}), confidence=0.9011561852569672, lift=1.0)]), RelationRecord(items=frozenset({'n'}), support=0.8313597783623848, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'n'}), confidence=0.8313597783623848, lift=1.0)]), RelationRecord(items=frozenset({'n', 'a'}), support=0.8089590687331782, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'n', 'a'}), confidence=0.8089590687331782, lift=1.0), OrderedStatistic(items_base=frozenset({'a'}), items_add=frozenset({'n'}), confidence=0.8976901917424018, lift=1.0797854492199213), OrderedStatistic(items_base=frozenset({'n'}), items_add=frozenset({'a'}), confidence=0.9730553363150048, lift=1.0797854492199213)])]
